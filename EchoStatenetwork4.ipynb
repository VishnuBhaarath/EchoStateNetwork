# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
from pyESN import ESN

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %%
df=pd.read_excel('trend_anna_imd_21.xlsx')

# %%
df.head()
# Out:
#             Unnamed: 0  Unnamed: 1
# 0         1. Cuddalore         NaN
# 1  1965-01-01 00:00:00        10.6
# 2  1965-01-02 00:00:00         0.0
# 3  1965-01-03 00:00:00        13.0
# 4  1965-01-04 00:00:00         0.0

# %%
Cuddalore=df[3655:19360]
Panruti=df[23016:38721]
Dharmapuri=df[42408:58082]
Harur=df[61738:77443]
Palacode=df[81158:96804]
Pennagaram=df[100460:116165]
Chengam=df[119821:135526]
Sathanur=df[138817:154522]
Tiruvanamalai=df[158178:173883]
Sankarapuram=df[177539:193244]
Tirukoilur=df[196899:212604]
ulundurpet=df[216260:231965]
Villupuram=df[235621:251326]
Denkanikottai=df[274343:290048]
Hosur=df[293703:309408]
Krishnagiri=df[313063:328768]
Marandahalli=df[332059:347764]
Rayakottai=df[353250:368955]
Uthangarai=df[372611:388316]

# %%
Cuddalore.columns = ['Date', 'Rainfall']
Panruti.columns= ['Date', 'Rainfall']
Dharmapuri.columns= ['Date', 'Rainfall']
Harur.columns= ['Date', 'Rainfall']
Palacode.columns= ['Date', 'Rainfall']
Pennagaram.columns= ['Date', 'Rainfall']
Chengam.columns= ['Date', 'Rainfall']
Sathanur.columns= ['Date', 'Rainfall']
Tiruvanamalai.columns= ['Date', 'Rainfall']
Sankarapuram.columns= ['Date', 'Rainfall']
Tirukoilur.columns= ['Date', 'Rainfall']
ulundurpet.columns= ['Date', 'Rainfall']
Villupuram.columns= ['Date', 'Rainfall']
Denkanikottai.columns= ['Date', 'Rainfall']
Hosur.columns= ['Date', 'Rainfall']
Krishnagiri.columns= ['Date', 'Rainfall']
Marandahalli.columns= ['Date', 'Rainfall']
Rayakottai.columns= ['Date', 'Rainfall']
Uthangarai.columns= ['Date', 'Rainfall']

# %%
train=Cuddalore[0:15704]
train1=Panruti[0:15705]
train2=Dharmapuri[0:15674]
train3=Harur[0:15704]
train4=Palacode[0:15646]
train5=Pennagaram[0:15705]
train6=Chengam[0:15705]
train7=Sathanur[0:15705]
train8=Tiruvanamalai[0:15165]
train9=Sankarapuram[0:15705]
train10=Tirukoilur[0:15705]
train11=ulundurpet[0:15345]
train12=Villupuram[0:15705]
train13=Denkanikottai[0:15705]
train14=Hosur[0:15678]
train15=Krishnagiri[0:15705]
train16=Marandahalli[0:15705]
train17=Rayakottai[0:15705]
train18=Uthangarai[0:15705]

# %%
X_train=train['Rainfall']
X_train1=train1['Rainfall']
X_train2=train2['Rainfall']
X_train3=train3['Rainfall']
X_train4=train4['Rainfall']
X_train5=train5['Rainfall']
X_train6=train6['Rainfall']
X_train7=train7['Rainfall']
X_train8=train8['Rainfall']
X_train9=train9['Rainfall']
X_train10=train10['Rainfall']
X_train11=train11['Rainfall']
X_train12=train12['Rainfall']
X_train13=train13['Rainfall']
X_train14=train14['Rainfall']
X_train15=train15['Rainfall']
X_train16=train16['Rainfall']
X_train17=train17['Rainfall']
X_train18=train18['Rainfall']

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()

x_scaled = min_max_scaler.fit_transform(X_train.values.reshape(-1,1))
X_train = pd.DataFrame(x_scaled)

x_scaled1 = min_max_scaler.fit_transform(X_train1.values.reshape(-1,1))
X_train1 = pd.DataFrame(x_scaled1)

x_scaled2 = min_max_scaler.fit_transform(X_train2.values.reshape(-1,1))
X_train2 = pd.DataFrame(x_scaled2)

x_scaled3 = min_max_scaler.fit_transform(X_train3.values.reshape(-1,1))
X_train3 = pd.DataFrame(x_scaled3)

x_scaled4 = min_max_scaler.fit_transform(X_train4.values.reshape(-1,1))
X_train4 = pd.DataFrame(x_scaled4)

x_scaled5 = min_max_scaler.fit_transform(X_train5.values.reshape(-1,1))
X_train5 = pd.DataFrame(x_scaled5)

x_scaled6 = min_max_scaler.fit_transform(X_train6.values.reshape(-1,1))
X_train6 = pd.DataFrame(x_scaled6)

x_scaled7 = min_max_scaler.fit_transform(X_train7.values.reshape(-1,1))
X_train7 = pd.DataFrame(x_scaled7)

x_scaled8 = min_max_scaler.fit_transform(X_train8.values.reshape(-1,1))
X_train8 = pd.DataFrame(x_scaled8)

x_scaled9 = min_max_scaler.fit_transform(X_train9.values.reshape(-1,1))
X_train9 = pd.DataFrame(x_scaled9)

x_scaled10 = min_max_scaler.fit_transform(X_train10.values.reshape(-1,1))
X_train10 = pd.DataFrame(x_scaled10)

x_scaled11 = min_max_scaler.fit_transform(X_train11.values.reshape(-1,1))
X_train11 = pd.DataFrame(x_scaled11)

x_scaled1112 = min_max_scaler.fit_transform(X_train12.values.reshape(-1,1))
X_train12 = pd.DataFrame(x_scaled1112)

x_scaled13 = min_max_scaler.fit_transform(X_train13.values.reshape(-1,1))
X_train13 = pd.DataFrame(x_scaled13)

x_scaled14 = min_max_scaler.fit_transform(X_train14.values.reshape(-1,1))
X_train14 = pd.DataFrame(x_scaled14)

x_scaled15 = min_max_scaler.fit_transform(X_train15.values.reshape(-1,1))
X_train15 = pd.DataFrame(x_scaled15)

x_scaled16 = min_max_scaler.fit_transform(X_train16.values.reshape(-1,1))
X_train16 = pd.DataFrame(x_scaled16)

x_scaled17 = min_max_scaler.fit_transform(X_train17.values.reshape(-1,1))
X_train17 = pd.DataFrame(x_scaled17)

x_scaled18 = min_max_scaler.fit_transform(X_train18.values.reshape(-1,1))
X_train18 = pd.DataFrame(x_scaled18)

# %%
in_seq = np.array([X_train[0]])

in_seq1 = np.array([X_train1[0]])


in_seq12 = np.array([X_train2[0]])


in_seq13 = np.array([X_train3[0]])


in_seq14 = np.array([X_train4[0]])


in_seq15 = np.array([X_train5[0]])


in_seq16 = np.array([X_train6[0]])


in_seq17 = np.array([X_train7[0]])


in_seq18 = np.array([X_train8[0]])


in_seq19 = np.array([X_train9[0]])


in_seq110 = np.array([X_train10[0]])


in_seq111 = np.array([X_train11[0]])


in_seq112 = np.array([X_train12[0]])


in_seq113 = np.array([X_train13[0]])


in_seq114 = np.array([X_train14[0]])


in_seq115 = np.array([X_train15[0]])


in_seq116 = np.array([X_train16[0]])


in_seq117 = np.array([X_train17[0]])


in_seq118 = np.array([X_train18[0]])

# %%
in_seq = in_seq.reshape((15704, 1))
in_seq1 = in_seq1.reshape((15705, 1))
in_seq12 = in_seq12.reshape((15674, 1))
in_seq13 = in_seq13.reshape((15704, 1))
in_seq14 = in_seq14.reshape((15646, 1))


in_seq15 = in_seq15.reshape((15705, 1))


in_seq16 = in_seq16.reshape((15705, 1))


in_seq17 = in_seq17.reshape((15705, 1))


in_seq18 = in_seq18.reshape((15165, 1))


in_seq19 = in_seq19.reshape((15705, 1))


in_seq110 = in_seq110.reshape((15705, 1))


in_seq111 = in_seq111.reshape((15345, 1))

in_seq112 = in_seq112.reshape((15705, 1))


in_seq113 = in_seq113.reshape((15705, 1))


in_seq114 = in_seq114.reshape((15678, 1))


in_seq115 = in_seq115.reshape((15705, 1))


in_seq116 = in_seq116.reshape((15705, 1))


in_seq117 = in_seq117.reshape((15705, 1))


in_seq118 = in_seq118.reshape((15704, 1))

# %%
n_reservoir= 500
sparsity=0.2
rand_seed=23
spectral_radius = 1.2
noise = .0005


esn = ESN(n_inputs = 1,
      n_outputs = 1, 
      n_reservoir = n_reservoir,
      sparsity=sparsity,
      random_state=rand_seed,
      spectral_radius = spectral_radius,
      noise=noise)

trainlen = 4
future = 2
futureTotal=4000
pred_tot=np.zeros(futureTotal)

# %%
for i in range(0,futureTotal,future):
    pred_training = esn.fit(np.ones(trainlen),in_seq[i:trainlen+i])
    prediction = esn.predict(np.ones(future))
    pred_tot[i:i+future] = prediction[:,0]

# %%
ypred1=pred_tot

# %%
ypred1.shape
# Out:
# (4000,)

# %%
yactual1=in_seq[4:4004]

# %%
r2_score(yactual1,ypred1)
# Out:
# -0.23976227564881958

# %%
mean_absolute_error(yactual1,ypred1)
# Out:
# 0.014693565461304771

# %%
mean_squared_error(yactual1,ypred1)
# Out:
# 0.0026064435432046223

# %%
s=pd.DataFrame(ypred1)
s1=pd.DataFrame(yactual1)
s1.corrwith(s, axis = 0)
# Out:
# 0    0.256668
# dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(range(10,trainlen+futureTotal),in_seq[10:trainlen+futureTotal],'b',label="Data", alpha=0.3)
#plt.plot(range(0,trainlen),pred_training,'.g',  alpha=0.3)
plt.plot(range(trainlen,trainlen+futureTotal),pred_tot,'k',  alpha=0.8, label='Free Running ESN')

lo,hi = plt.ylim()
plt.plot([trainlen,trainlen],[lo+np.spacing(1),hi-np.spacing(1)],'k:', linewidth=4)

plt.title(r'Ground Truth and Echo State Network Output', fontsize=25)
plt.xlabel(r'Time (Days)', fontsize=20,labelpad=10)
plt.ylabel(r'Rainfall (mm)', fontsize=20,labelpad=10)
plt.legend(fontsize='xx-large', loc='best')
sns.despine()

# %%
for i in range(0,futureTotal,future):
    pred_training = esn.fit(np.ones(trainlen),in_seq1[i:trainlen+i])
    prediction = esn.predict(np.ones(future))
    pred_tot[i:i+future] = prediction[:,0]

# %%
ypred1=pred_tot
yactual1=in_seq1[4:4004]

# %%
r2_score(yactual1,ypred1)
# Out:
# -0.3627325419772369

# %%
s=pd.DataFrame(ypred1)
s1=pd.DataFrame(yactual1)
s1.corrwith(s, axis = 0)
# Out:
# 0    0.178535
# dtype: float64

# %%
mean_absolute_error(yactual1,ypred1)
# Out:
# 1.4734068705354179e-05

# %%
mean_squared_error(yactual1,ypred1)
# Out:
# 2.0829675804691234e-09

# %%
plt.figure(figsize=(16,8))
plt.plot(range(10,trainlen+futureTotal),in_seq1[10:trainlen+futureTotal],'b',label="Data", alpha=0.3)
#plt.plot(range(0,trainlen),pred_training,'.g',  alpha=0.3)
plt.plot(range(trainlen,trainlen+futureTotal),pred_tot,'k',  alpha=0.8, label='Free Running ESN')

lo,hi = plt.ylim()
plt.plot([trainlen,trainlen],[lo+np.spacing(1),hi-np.spacing(1)],'k:', linewidth=4)

plt.title(r'Ground Truth and Echo State Network Output', fontsize=25)
plt.xlabel(r'Time (Days)', fontsize=20,labelpad=10)
plt.ylabel(r'Rainfall (mm)', fontsize=20,labelpad=10)
plt.legend(fontsize='xx-large', loc='best')
sns.despine()

# %%
for i in range(0,futureTotal,future):
    pred_training = esn.fit(np.ones(trainlen),in_seq12[i:trainlen+i])
    prediction = esn.predict(np.ones(future))
    pred_tot[i:i+future] = prediction[:,0]

# %%
ypred2=pred_tot
yactual2=in_seq12[4:4004]

# %%
mean_absolute_error(yactual2,ypred2)
# Out:
# 0.01636084259677223

# %%
r2_score(yactual2,ypred2)
# Out:
# -0.26635605561794184

# %%
s=pd.DataFrame(ypred2)
s1=pd.DataFrame(yactual2)
s1.corrwith(s, axis = 0)
# Out:
# 0    0.202011
# dtype: float64

# %%
mean_squared_error(yactual2,ypred2)
# Out:
# 0.0018728219743664128

# %%
plt.figure(figsize=(16,8))
plt.plot(range(10,trainlen+futureTotal),in_seq12[10:trainlen+futureTotal],'b',label="Data", alpha=0.3)
#plt.plot(range(0,trainlen),pred_training,'.g',  alpha=0.3)
plt.plot(range(trainlen,trainlen+futureTotal),pred_tot,'k',  alpha=0.8, label='Free Running ESN')

lo,hi = plt.ylim()
plt.plot([trainlen,trainlen],[lo+np.spacing(1),hi-np.spacing(1)],'k:', linewidth=4)

plt.title(r'Ground Truth and Echo State Network Output', fontsize=25)
plt.xlabel(r'Time (Days)', fontsize=20,labelpad=10)
plt.ylabel(r'Rainfall (mm)', fontsize=20,labelpad=10)
plt.legend(fontsize='xx-large', loc='best')
sns.despine()

# %%
for i in range(0,futureTotal,future):
    pred_training = esn.fit(np.ones(trainlen),in_seq13[i:trainlen+i])
    prediction = esn.predict(np.ones(future))
    pred_tot[i:i+future] = prediction[:,0]

# %%
ypred3=pred_tot
yactual3=in_seq13[4:4004]

# %%
r2_score(yactual3,ypred3)
# Out:
# -0.20286822152084194

# %%
mean_absolute_error(yactual3,ypred3)
# Out:
# 0.021473987227923513

# %%
s=pd.DataFrame(ypred3)
s1=pd.DataFrame(yactual3)
s1.corrwith(s, axis = 0)
# Out:
# 0    0.24248
# dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(range(10,trainlen+futureTotal),in_seq13[10:trainlen+futureTotal],'b',label="Data", alpha=0.3)
#plt.plot(range(0,trainlen),pred_training,'.g',  alpha=0.3)
plt.plot(range(trainlen,trainlen+futureTotal),pred_tot,'k',  alpha=0.8, label='Free Running ESN')

lo,hi = plt.ylim()
plt.plot([trainlen,trainlen],[lo+np.spacing(1),hi-np.spacing(1)],'k:', linewidth=4)

plt.title(r'Ground Truth and Echo State Network Output', fontsize=25)
plt.xlabel(r'Time (Days)', fontsize=20,labelpad=10)
plt.ylabel(r'Rainfall (mm)', fontsize=20,labelpad=10)
plt.legend(fontsize='xx-large', loc='best')
sns.despine()

# %%
for i in range(0,futureTotal,future):
    pred_training = esn.fit(np.ones(trainlen),in_seq14[i:trainlen+i])
    prediction = esn.predict(np.ones(future))
    pred_tot[i:i+future] = prediction[:,0]

# %%
ypred4=pred_tot
yactual4=in_seq14[4:4004]

# %%
r2_score(yactual4,ypred4)
# Out:
# -0.2517251437613035

# %%
mean_absolute_error(yactual4,ypred4)
# Out:
# 0.015760856155110466

# %%
s=pd.DataFrame(ypred4)
s1=pd.DataFrame(yactual4)
s1.corrwith(s, axis = 0)
# Out:
# 0    0.211775
# dtype: float64

# %%
mean_squared_error(yactual4,ypred4)
# Out:
# 0.0019198338273035298

# %%
plt.figure(figsize=(16,8))
plt.plot(range(10,trainlen+futureTotal),in_seq14[10:trainlen+futureTotal],'b',label="Data", alpha=0.3)
#plt.plot(range(0,trainlen),pred_training,'.g',  alpha=0.3)
plt.plot(range(trainlen,trainlen+futureTotal),pred_tot,'k',  alpha=0.8, label='Free Running ESN')

lo,hi = plt.ylim()
plt.plot([trainlen,trainlen],[lo+np.spacing(1),hi-np.spacing(1)],'k:', linewidth=4)

plt.title(r'Ground Truth and Echo State Network Output', fontsize=25)
plt.xlabel(r'Time (Days)', fontsize=20,labelpad=10)
plt.ylabel(r'Rainfall (mm)', fontsize=20,labelpad=10)
plt.legend(fontsize='xx-large', loc='best')
sns.despine()

# %%
for i in range(0,futureTotal,future):
    pred_training = esn.fit(np.ones(trainlen),in_seq15[i:trainlen+i])
    prediction = esn.predict(np.ones(future))
    pred_tot[i:i+future] = prediction[:,0]

# %%
ypred5=pred_tot
yactual5=in_seq15[4:4004]

# %%
r2_score(yactual5,ypred5)
# Out:
# -0.24810958503291913

# %%
mean_absolute_error(yactual5,ypred5)
# Out:
# 0.01713289483793322

# %%
s=pd.DataFrame(ypred5)
s1=pd.DataFrame(yactual5)
s1.corrwith(s, axis = 0)
# Out:
# 0    0.20859
# dtype: float64

# %%
mean_squared_error(yactual5,ypred5)
# Out:
# 0.0021761356571719996

# %%
plt.figure(figsize=(16,8))
plt.plot(range(10,trainlen+futureTotal),in_seq15[10:trainlen+futureTotal],'b',label="Data", alpha=0.3)
#plt.plot(range(0,trainlen),pred_training,'.g',  alpha=0.3)
plt.plot(range(trainlen,trainlen+futureTotal),pred_tot,'k',  alpha=0.8, label='Free Running ESN')

lo,hi = plt.ylim()
plt.plot([trainlen,trainlen],[lo+np.spacing(1),hi-np.spacing(1)],'k:', linewidth=4)

plt.title(r'Ground Truth and Echo State Network Output', fontsize=25)
plt.xlabel(r'Time (Days)', fontsize=20,labelpad=10)
plt.ylabel(r'Rainfall (mm)', fontsize=20,labelpad=10)
plt.legend(fontsize='xx-large', loc='best')
sns.despine()

# %%
for i in range(0,futureTotal,future):
    pred_training = esn.fit(np.ones(trainlen),in_seq16[i:trainlen+i])
    prediction = esn.predict(np.ones(future))
    pred_tot[i:i+future] = prediction[:,0]

# %%
ypred6=pred_tot
yactual6=in_seq16[4:4004]

# %%
r2_score(yactual6,ypred6)
# Out:
# -0.24904449727984845

# %%
mean_absolute_error(yactual6,ypred6)
# Out:
# 0.023611023974520255

# %%
s=pd.DataFrame(ypred6)
s1=pd.DataFrame(yactual6)
s1.corrwith(s, axis = 0)
# Out:
# 0    0.234754
# dtype: float64

# %%
mean_squared_error(yactual6,ypred6)
# Out:
# 0.003503496356945137

# %%
plt.figure(figsize=(16,8))
plt.plot(range(10,trainlen+futureTotal),in_seq16[10:trainlen+futureTotal],'b',label="Data", alpha=0.3)
#plt.plot(range(0,trainlen),pred_training,'.g',  alpha=0.3)
plt.plot(range(trainlen,trainlen+futureTotal),pred_tot,'k',  alpha=0.8, label='Free Running ESN')

lo,hi = plt.ylim()
plt.plot([trainlen,trainlen],[lo+np.spacing(1),hi-np.spacing(1)],'k:', linewidth=4)

plt.title(r'Ground Truth and Echo State Network Output', fontsize=25)
plt.xlabel(r'Time (Days)', fontsize=20,labelpad=10)
plt.ylabel(r'Rainfall (mm)', fontsize=20,labelpad=10)
plt.legend(fontsize='xx-large', loc='best')
sns.despine()

# %%
for i in range(0,futureTotal,future):
    pred_training = esn.fit(np.ones(trainlen),in_seq17[i:trainlen+i])
    prediction = esn.predict(np.ones(future))
    pred_tot[i:i+future] = prediction[:,0]

# %%
yactual7=in_seq17[4:4004]
ypred7=pred_tot

# %%
r2_score(yactual7,ypred7)
# Out:
# -0.2237120301149944

# %%
mean_absolute_error(yactual7,ypred7)
# Out:
# 0.016672774208285307

# %%
plt.figure(figsize=(16,8))
plt.plot(range(10,trainlen+futureTotal),in_seq17[10:trainlen+futureTotal],'b',label="Data", alpha=0.3)
#plt.plot(range(0,trainlen),pred_training,'.g',  alpha=0.3)
plt.plot(range(trainlen,trainlen+futureTotal),pred_tot,'k',  alpha=0.8, label='Free Running ESN')

lo,hi = plt.ylim()
plt.plot([trainlen,trainlen],[lo+np.spacing(1),hi-np.spacing(1)],'k:', linewidth=4)

plt.title(r'Ground Truth and Echo State Network Output', fontsize=25)
plt.xlabel(r'Time (Days)', fontsize=20,labelpad=10)
plt.ylabel(r'Rainfall (mm)', fontsize=20,labelpad=10)
plt.legend(fontsize='xx-large', loc='best')
sns.despine()

# %%
for i in range(0,futureTotal,future):
    pred_training = esn.fit(np.ones(trainlen),in_seq18[i:trainlen+i])
    prediction = esn.predict(np.ones(future))
    pred_tot[i:i+future] = prediction[:,0]

# %%
yactual8=in_seq18[4:4004]
ypred8=pred_tot

# %%
r2_score(yactual8,ypred8)
# Out:
# -0.09273076525590018

# %%
mean_absolute_error(yactual8,ypred8)
# Out:
# 0.022115418247331844

# %%
s=pd.DataFrame(ypred8)
s1=pd.DataFrame(yactual8)
s1.corrwith(s, axis = 0)
# Out:
# 0    0.312848
# dtype: float64

# %%
mean_squared_error(yactual8,ypred8)
# Out:
# 0.003311470586991863

# %%
plt.figure(figsize=(16,8))
plt.plot(range(10,trainlen+futureTotal),in_seq18[10:trainlen+futureTotal],'b',label="Data", alpha=0.3)
#plt.plot(range(0,trainlen),pred_training,'.g',  alpha=0.3)
plt.plot(range(trainlen,trainlen+futureTotal),pred_tot,'k',  alpha=0.8, label='Free Running ESN')

lo,hi = plt.ylim()
plt.plot([trainlen,trainlen],[lo+np.spacing(1),hi-np.spacing(1)],'k:', linewidth=4)

plt.title(r'Ground Truth and Echo State Network Output', fontsize=25)
plt.xlabel(r'Time (Days)', fontsize=20,labelpad=10)
plt.ylabel(r'Rainfall (mm)', fontsize=20,labelpad=10)
plt.legend(fontsize='xx-large', loc='best')
sns.despine()

# %%
for i in range(0,futureTotal,future):
    pred_training = esn.fit(np.ones(trainlen),in_seq19[i:trainlen+i])
    prediction = esn.predict(np.ones(future))
    pred_tot[i:i+future] = prediction[:,0]

# %%
yactual9=in_seq19[4:4004]
ypred9=pred_tot

# %%
mean_absolute_error(yactual9,ypred9)
# Out:
# 1.3152317625685367e-05

# %%
r2_score(yactual9,ypred9)
# Out:
# -0.19486037854988236

# %%
s=pd.DataFrame(ypred9)
s1=pd.DataFrame(yactual9)
s1.corrwith(s, axis = 0)
# Out:
# 0    0.258749
# dtype: float64

# %%
mean_squared_error(yactual9,ypred9)
# Out:
# 1.3865914739730176e-09

# %%
plt.figure(figsize=(16,8))
plt.plot(range(10,trainlen+futureTotal),in_seq19[10:trainlen+futureTotal],'b',label="Data", alpha=0.3)
#plt.plot(range(0,trainlen),pred_training,'.g',  alpha=0.3)
plt.plot(range(trainlen,trainlen+futureTotal),pred_tot,'k',  alpha=0.8, label='Free Running ESN')

lo,hi = plt.ylim()
plt.plot([trainlen,trainlen],[lo+np.spacing(1),hi-np.spacing(1)],'k:', linewidth=4)

plt.title(r'Ground Truth and Echo State Network Output', fontsize=25)
plt.xlabel(r'Time (Days)', fontsize=20,labelpad=10)
plt.ylabel(r'Rainfall (mm)', fontsize=20,labelpad=10)
plt.legend(fontsize='xx-large', loc='best')
sns.despine()

# %%
for i in range(0,futureTotal,future):
    pred_training = esn.fit(np.ones(trainlen),in_seq110[i:trainlen+i])
    prediction = esn.predict(np.ones(future))
    pred_tot[i:i+future] = prediction[:,0]

# %%
yactual9=in_seq110[4:4004]
ypred9=pred_tot

# %%
mean_absolute_error(yactual9,ypred9)
# Out:
# 1.3255779656021289e-05

# %%
mean_squared_error(yactual9,ypred9)
# Out:
# 1.342602893895893e-09

# %%
r2_score(yactual9,ypred9)
# Out:
# -0.3043847290371977

# %%
s=pd.DataFrame(ypred9)
s1=pd.DataFrame(yactual9)
s1.corrwith(s, axis = 0)
# Out:
# 0    0.190814
# dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(range(10,trainlen+futureTotal),in_seq110[10:trainlen+futureTotal],'b',label="Data", alpha=0.3)
#plt.plot(range(0,trainlen),pred_training,'.g',  alpha=0.3)
plt.plot(range(trainlen,trainlen+futureTotal),pred_tot,'k',  alpha=0.8, label='Free Running ESN')

lo,hi = plt.ylim()
plt.plot([trainlen,trainlen],[lo+np.spacing(1),hi-np.spacing(1)],'k:', linewidth=4)

plt.title(r'Ground Truth and Echo State Network Output', fontsize=25)
plt.xlabel(r'Time (Days)', fontsize=20,labelpad=10)
plt.ylabel(r'Rainfall (mm)', fontsize=20,labelpad=10)
plt.legend(fontsize='xx-large', loc='best')
sns.despine()

# %%
for i in range(0,futureTotal,future):
    pred_training = esn.fit(np.ones(trainlen),in_seq111[i:trainlen+i])
    prediction = esn.predict(np.ones(future))
    pred_tot[i:i+future] = prediction[:,0]

# %%
yactual11=in_seq111[4:4004]
ypred11=pred_tot

# %%
mean_absolute_error(yactual11,ypred11)
# Out:
# 1.3323639180042505e-05

# %%
r2_score(yactual11,ypred11)
# Out:
# -0.2008406344191671

# %%
s=pd.DataFrame(ypred11)
s1=pd.DataFrame(yactual11)
s1.corrwith(s, axis = 0)
# Out:
# 0    0.212934
# dtype: float64

# %%
mean_squared_error(yactual11,ypred11)
# Out:
# 1.3521531592281182e-09

# %%
plt.figure(figsize=(16,8))
plt.plot(range(10,trainlen+futureTotal),in_seq111[10:trainlen+futureTotal],'b',label="Data", alpha=0.3)
#plt.plot(range(0,trainlen),pred_training,'.g',  alpha=0.3)
plt.plot(range(trainlen,trainlen+futureTotal),pred_tot,'k',  alpha=0.8, label='Free Running ESN')

lo,hi = plt.ylim()
plt.plot([trainlen,trainlen],[lo+np.spacing(1),hi-np.spacing(1)],'k:', linewidth=4)

plt.title(r'Ground Truth and Echo State Network Output', fontsize=25)
plt.xlabel(r'Time (Days)', fontsize=20,labelpad=10)
plt.ylabel(r'Rainfall (mm)', fontsize=20,labelpad=10)
plt.legend(fontsize='xx-large', loc='best')
sns.despine()

# %%
for i in range(0,futureTotal,future):
    pred_training = esn.fit(np.ones(trainlen),in_seq112[i:trainlen+i])
    prediction = esn.predict(np.ones(future))
    pred_tot[i:i+future] = prediction[:,0]

# %%
yactual12=in_seq112[4:4004]
ypred12=pred_tot

# %%
mean_absolute_error(yactual12,ypred12)
# Out:
# 1.3595838532272987e-05

# %%
mean_squared_error(yactual12,ypred12)
# Out:
# 1.3298413117260483e-09

# %%
r2_score(yactual12,ypred12)
# Out:
# -0.24569136164365468

# %%
s=pd.DataFrame(ypred12)
s1=pd.DataFrame(yactual12)
s1.corrwith(s, axis = 0)
# Out:
# 0    0.246006
# dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(range(10,trainlen+futureTotal),in_seq112[10:trainlen+futureTotal],'b',label="Data", alpha=0.3)
#plt.plot(range(0,trainlen),pred_training,'.g',  alpha=0.3)
plt.plot(range(trainlen,trainlen+futureTotal),pred_tot,'k',  alpha=0.8, label='Free Running ESN')

lo,hi = plt.ylim()
plt.plot([trainlen,trainlen],[lo+np.spacing(1),hi-np.spacing(1)],'k:', linewidth=4)

plt.title(r'Ground Truth and Echo State Network Output', fontsize=25)
plt.xlabel(r'Time (Days)', fontsize=20,labelpad=10)
plt.ylabel(r'Rainfall (mm)', fontsize=20,labelpad=10)
plt.legend(fontsize='xx-large', loc='best')
sns.despine()

# %%
for i in range(0,futureTotal,future):
    pred_training = esn.fit(np.ones(trainlen),in_seq113[i:trainlen+i])
    prediction = esn.predict(np.ones(future))
    pred_tot[i:i+future] = prediction[:,0]

# %%
yactual13=in_seq113[4:4004]
ypred13=pred_tot

# %%
mean_absolute_error(yactual13,ypred13)
# Out:
# 1.3323567765543926e-05

# %%
mean_squared_error(yactual13,ypred13)
# Out:
# 1.3521411242779303e-09

# %%
r2_score(yactual13,ypred13)
# Out:
# -0.200829946238527

# %%
s=pd.DataFrame(ypred13)
s1=pd.DataFrame(yactual13)
s1.corrwith(s, axis = 0)
# Out:
# 0    0.21294
# dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(range(10,trainlen+futureTotal),in_seq113[10:trainlen+futureTotal],'b',label="Data", alpha=0.3)
#plt.plot(range(0,trainlen),pred_training,'.g',  alpha=0.3)
plt.plot(range(trainlen,trainlen+futureTotal),pred_tot,'k',  alpha=0.8, label='Free Running ESN')

lo,hi = plt.ylim()
plt.plot([trainlen,trainlen],[lo+np.spacing(1),hi-np.spacing(1)],'k:', linewidth=4)

plt.title(r'Ground Truth and Echo State Network Output', fontsize=25)
plt.xlabel(r'Time (Days)', fontsize=20,labelpad=10)
plt.ylabel(r'Rainfall (mm)', fontsize=20,labelpad=10)
plt.legend(fontsize='xx-large', loc='best')
sns.despine()

# %%
for i in range(0,futureTotal,future):
    pred_training = esn.fit(np.ones(trainlen),in_seq114[i:trainlen+i])
    prediction = esn.predict(np.ones(future))
    pred_tot[i:i+future] = prediction[:,0]

# %%
yactual14=in_seq114[4:4004]
ypred14=pred_tot

# %%
mean_absolute_error(yactual14,ypred14)
# Out:
# 0.017602551691270927

# %%
r2_score(yactual14,ypred14)
# Out:
# -0.2575035246851678

# %%
mean_absolute_error(yactual14,ypred14)
# Out:
# 0.017602551691270927

# %%
s=pd.DataFrame(ypred14)
s1=pd.DataFrame(yactual14)
s1.corrwith(s, axis = 0)
# Out:
# 0    0.18273
# dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(range(10,trainlen+futureTotal),in_seq114[10:trainlen+futureTotal],'b',label="Data", alpha=0.3)
#plt.plot(range(0,trainlen),pred_training,'.g',  alpha=0.3)
plt.plot(range(trainlen,trainlen+futureTotal),pred_tot,'k',  alpha=0.8, label='Free Running ESN')

lo,hi = plt.ylim()
plt.plot([trainlen,trainlen],[lo+np.spacing(1),hi-np.spacing(1)],'k:', linewidth=4)

plt.title(r'Ground Truth and Echo State Network Output', fontsize=25)
plt.xlabel(r'Time (Days)', fontsize=20,labelpad=10)
plt.ylabel(r'Rainfall (mm)', fontsize=20,labelpad=10)
plt.legend(fontsize='xx-large', loc='best')
sns.despine()

# %%
for i in range(0,futureTotal,future):
    pred_training = esn.fit(np.ones(trainlen),in_seq115[i:trainlen+i])
    prediction = esn.predict(np.ones(future))
    pred_tot[i:i+future] = prediction[:,0]

# %%
yactual15=in_seq115[4:4004]
ypred15=pred_tot

# %%
mean_absolute_error(yactual15,ypred15)
# Out:
# 0.02007043767830851

# %%
mean_squared_error(yactual15,ypred15)
# Out:
# 0.0033299645867515314

# %%
r2_score(yactual15,ypred15)
# Out:
# -0.2999225948821047

# %%
plt.figure(figsize=(16,8))
plt.plot(range(10,trainlen+futureTotal),in_seq115[10:trainlen+futureTotal],'b',label="Data", alpha=0.3)
#plt.plot(range(0,trainlen),pred_training,'.g',  alpha=0.3)
plt.plot(range(trainlen,trainlen+futureTotal),pred_tot,'k',  alpha=0.8, label='Free Running ESN')

lo,hi = plt.ylim()
plt.plot([trainlen,trainlen],[lo+np.spacing(1),hi-np.spacing(1)],'k:', linewidth=4)

plt.title(r'Ground Truth and Echo State Network Output', fontsize=25)
plt.xlabel(r'Time (Days)', fontsize=20,labelpad=10)
plt.ylabel(r'Rainfall (mm)', fontsize=20,labelpad=10)
plt.legend(fontsize='xx-large', loc='best')
sns.despine()

# %%
s=pd.DataFrame(ypred15)
s1=pd.DataFrame(yactual15)
s1.corrwith(s, axis = 0)
# Out:
# 0    0.167476
# dtype: float64

# %%
for i in range(0,futureTotal,future):
    pred_training = esn.fit(np.ones(trainlen),in_seq116[i:trainlen+i])
    prediction = esn.predict(np.ones(future))
    pred_tot[i:i+future] = prediction[:,0]

# %%
yactual16=in_seq116[4:4004]
ypred16=pred_tot

# %%
mean_absolute_error(yactual16,ypred16)
# Out:
# 0.0159611654074994

# %%
mean_squared_error(yactual16,ypred16)
# Out:
# 0.0020971547155004444

# %%
r2_score(yactual16,ypred16)
# Out:
# -0.2502583548400914

# %%
s=pd.DataFrame(ypred16)
s1=pd.DataFrame(yactual16)
s1.corrwith(s, axis = 0)
# Out:
# 0    0.202555
# dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(range(10,trainlen+futureTotal),in_seq116[10:trainlen+futureTotal],'b',label="Data", alpha=0.3)
#plt.plot(range(0,trainlen),pred_training,'.g',  alpha=0.3)
plt.plot(range(trainlen,trainlen+futureTotal),pred_tot,'k',  alpha=0.8, label='Free Running ESN')

lo,hi = plt.ylim()
plt.plot([trainlen,trainlen],[lo+np.spacing(1),hi-np.spacing(1)],'k:', linewidth=4)

plt.title(r'Ground Truth and Echo State Network Output', fontsize=25)
plt.xlabel(r'Time (Days)', fontsize=20,labelpad=10)
plt.ylabel(r'Rainfall (mm)', fontsize=20,labelpad=10)
plt.legend(fontsize='xx-large', loc='best')
sns.despine()

# %%
for i in range(0,futureTotal,future):
    pred_training = esn.fit(np.ones(trainlen),in_seq117[i:trainlen+i])
    prediction = esn.predict(np.ones(future))
    pred_tot[i:i+future] = prediction[:,0]

# %%
yactual17=in_seq117[4:4004]
ypred17=pred_tot

# %%
mean_absolute_error(yactual17,ypred17)
# Out:
# 0.01500598340433091

# %%
mean_squared_error(yactual17,ypred17)
# Out:
# 0.003067910250928945

# %%
r2_score(yactual17,ypred17)
# Out:
# -0.29042166323948915

# %%
s=pd.DataFrame(ypred17)
s1=pd.DataFrame(yactual17)
s1.corrwith(s, axis = 0)
# Out:
# 0    0.185041
# dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(range(10,trainlen+futureTotal),in_seq117[10:trainlen+futureTotal],'b',label="Data", alpha=0.3)
#plt.plot(range(0,trainlen),pred_training,'.g',  alpha=0.3)
plt.plot(range(trainlen,trainlen+futureTotal),pred_tot,'k',  alpha=0.8, label='Free Running ESN')

lo,hi = plt.ylim()
plt.plot([trainlen,trainlen],[lo+np.spacing(1),hi-np.spacing(1)],'k:', linewidth=4)

plt.title(r'Ground Truth and Echo State Network Output', fontsize=25)
plt.xlabel(r'Time (Days)', fontsize=20,labelpad=10)
plt.ylabel(r'Rainfall (mm)', fontsize=20,labelpad=10)
plt.legend(fontsize='xx-large', loc='best')
sns.despine()

# %%
for i in range(0,futureTotal,future):
    pred_training = esn.fit(np.ones(trainlen),in_seq118[i:trainlen+i])
    prediction = esn.predict(np.ones(future))
    pred_tot[i:i+future] = prediction[:,0]

# %%
yactual18=in_seq118[4:4004]
ypred18=pred_tot

# %%
mean_absolute_error(yactual18,ypred18)
# Out:
# 0.0031584816235701333

# %%
mean_squared_error(yactual18,ypred18)
# Out:
# 8.19680613845167e-05

# %%
r2_score(yactual18,ypred18)
# Out:
# -0.2726471114481577

# %%
s=pd.DataFrame(ypred18)
s1=pd.DataFrame(yactual18)
s1.corrwith(s, axis = 0)
# Out:
# 0    0.186636
# dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(range(10,trainlen+futureTotal),in_seq118[10:trainlen+futureTotal],'b',label="Data", alpha=0.3)
#plt.plot(range(0,trainlen),pred_training,'.g',  alpha=0.3)
plt.plot(range(trainlen,trainlen+futureTotal),pred_tot,'k',  alpha=0.8, label='Free Running ESN')

lo,hi = plt.ylim()
plt.plot([trainlen,trainlen],[lo+np.spacing(1),hi-np.spacing(1)],'k:', linewidth=4)

plt.title(r'Ground Truth and Echo State Network Output', fontsize=25)
plt.xlabel(r'Time (Days)', fontsize=20,labelpad=10)
plt.ylabel(r'Rainfall (mm)', fontsize=20,labelpad=10)
plt.legend(fontsize='xx-large', loc='best')
sns.despine()
